# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("valid.csv")
df
# Out:
#             date  Close  Predicted
# 0     2009-01-01     15        NaN
# 1     2009-01-02     15        NaN
# 2     2009-01-05     15        NaN
# 3     2009-01-06     15        NaN
# 4     2009-01-07     15        NaN
# ...          ...    ...        ...
# 4569  2023-09-26     36  35.569031
# 4570  2023-09-27     36  35.909260
# 4571  2023-09-28     36  36.221233
# 4572  2023-09-29     35  36.433865
# 4573  2023-09-30     36  36.231003
#
# [4574 rows x 3 columns]

# %%
plt.plot(df['date'],df['Predicted'])
plt.show()
